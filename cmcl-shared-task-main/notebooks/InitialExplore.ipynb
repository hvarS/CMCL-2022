# %% [markdown]
# # Some initial exploration

# %%
import sys
sys.path.append('../')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tqdm
import torch
from collections import defaultdict, Counter
import random
import math
import pickle

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv("../../training_data2022/training_data/train_and_valid.csv")

# %%
df[df.sentence_id == 'ZuCo1-1']
# Out:
#    language sentence_id  word_id      word    FFDAvg    FFDStd     TRTAvg  \
# 0        en     ZuCo1-1      0.0      With  7.413838  2.919451   8.249414
# 1        en     ZuCo1-1      1.0       his  6.781839  3.237881  11.959371
# 2        en     ZuCo1-1      2.0  interest  6.980858  2.166715   9.479990
# 3        en     ZuCo1-1      3.0        in  4.405764  0.544554   4.405764
# 4        en     ZuCo1-1      4.0      race  7.403710  6.004217   8.163324
# 5        en     ZuCo1-1      5.0     cars,  6.684608  1.890888  11.142855
# 6        en     ZuCo1-1      6.0        he  5.590763  1.676759  16.383367
# 7        en     ZuCo1-1      7.0    formed  7.997222  3.057467   9.236913
# 8        en     ZuCo1-1      8.0         a  5.975634  2.107735   6.907428
# 9        en     ZuCo1-1      9.0    second  8.507683  0.000000   8.507683
# 10       en     ZuCo1-1     10.0  company,  6.198455  2.807684   9.510374
# 11       en     ZuCo1-1     11.0       the  7.037069  2.560395   7.037069
# 12       en     ZuCo1-1     12.0     Henry  6.708916  2.457994  11.442834
# 13       en     ZuCo1-1     13.0      Ford  7.687299  2.688573  24.252973
# 14       en     ZuCo1-1     14.0  Company.  6.113378  3.159295   7.389530
#
#        TRTStd
# 0    3.091224
# 1    9.234372
# 2    4.911090
# 3    0.544554
# 4    5.685950
# 5    6.942237
# 6   10.152279
# 7    5.288120
# 8    3.194141
# 9    0.000000
# 10   2.610993
# 11   2.560395
# 12   5.677143
# 13  15.537229
# 14   3.627771

# %%
df.describe()
# Out:
#             word_id        FFDAvg        FFDStd        TRTAvg        TRTStd
# count  27780.000000  27780.000000  27780.000000  27780.000000  27780.000000
# mean      21.531066     13.031796      4.485098     18.946597      9.908437
# std       23.679286      7.372658      3.564683     11.617641      8.030134
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        6.000000      7.585097      2.087925     10.701241      4.321890
# 50%       12.000000     11.074771      3.575453     15.172901      7.842472
# 75%       27.000000     16.203276      5.881854     24.830243     13.425560
# max      135.000000     56.735847     58.544324    100.000000    100.000000

# %%
sns.set_style("white")
g = sns.pairplot(df[['FFDAvg', 'FFDStd', 'TRTAvg', 'TRTStd']],
                 corner=True, height=1.2, plot_kws={'edgecolor':"none", 's':3})
#g.set(xlim=(0, 100))
g.axes[0, 0].set_xlim((0, 100))
g.axes[1, 1].set_xlim((0, 12))
g.axes[2, 2].set_xlim((0, 70))
g.axes[3, 3].set_xlim((0, 40))
plt.show()
